# %% [markdown]
# <h1 style="padding:50px; color:white; background:#07D; font-size:48px; text-align:center; font-weight:bold;">
#     Projet - OUTINFO
# </h1>

# %%
import numpy as np # import du package 'numpy' avec alias 'np'
import pandas as pd # import du package 'pandas' avec alias 'pd'
from SRC.tools import show, inspect  # import des fonctions du module 'tools'
from IPython.core.interactiveshell import InteractiveShell as ish

import matplotlib.pyplot as mp # import du package 'matplotlib' avec alias 'mp'
import seaborn as sb # import du package 'seaborn' avec alias 'sb'

from SRC.tools import show, load, fetch

from bs4 import BeautifulSoup
import requests

import geopandas as gpd

import requests
from io import StringIO

import folium
from IPython.display import display, HTML
from ipywidgets import interact, widgets

import warnings; warnings.filterwarnings('ignore') # on enlève les 'warning' éventuels

# %% [markdown]
# <h2 style="padding:16px; color:white; background:#07D">Travail envisagé</h2>

# %% [markdown]
# **Données:**
#
# - https://public.opendatasoft.com/explore/dataset/medecins/information/?flg=fr&location=8,48.49659,1.94733&basemap=jawg.light
#
# Liste, localisation et tarifs des professionnels de santé en France.
#
# Format : GeoJSON
#
# <br>
#
# - https://statistiques-locales.insee.fr/#c=indicator&i=filosofi.nbmenfisc&i2=filosofi.pimp&s=2021&s2=2021&selcodgeo=04&t=A01&t2=A01&view=map2
#
# Statistiques locales en France: nombre d'habitants par zone, niveau de vie moyen par zone, espérance de vie, répartition de la population par âge, etc.
#
# Format : CSV
# <br>
#
# - https://www.regions-et-departements.fr/
#
# Départements associés à leur région. \
# Téléchargement des données en format PDF puis utilisation d'un convertisseur en ligne afin d'obtenir les données en format HTML.
#
# Format : HTML
#
# <br>
#
# - https://www.openstreetmap.fr/
#
# Les adjacences des communes françaises (avec une requête sql)
#
# <br>

# %% [markdown]
# **Analyses envisagées:**
#
# - Concentration des medecins par departement
#
# - Comparer la concentration entre les zones rurales et urbaines
#
# - Calculer le nombre de patient par medecin, à l'aide de leur localisation et de l'adjacence des communes
#
# - Le montant constaté par séance par medecin par patient, et le niveau de revenu moyen de ses patients

# %% [markdown]
# <br> <br>
#
# <h2 style="padding:16px; color:white; background:#07D">Etape 1 - Maillon fetch</h2>
#
# <br> <br>
#
# ---
# ### 1 - Statistiques locales en France
#
# <br>
# Le fichier a été téléchargé, puis déposé sur GitHub, pour pouvoir y accéder à l'aide d'un url.
#
# Les séparateurs sont '$;$' et les deux premières lignes sont à ignorer.

# %%
# URL GitHub pour le fichier CSV
url = "https://raw.githubusercontent.com/ahina0/projet_outinfo/main/statistiques.csv"

# Télécharger le fichier CSV depuis GitHub
response = requests.get(url)
response.raise_for_status()
    
# Charger les données dans un DataFrame
statistiques = pd.read_csv(StringIO(response.text), sep=';', skiprows=2)
statistiques
# Out:
#     Code                  Libellé  Médecin généraliste (en nombre) 2023  \
# 0     01                      Ain                                   435
# 1     02                    Aisne                                   372
# 2     03                   Allier                                   278
# 3     04  Alpes-de-Haute-Provence                                   169
# 4     05             Hautes-Alpes                                   182
# ..   ...                      ...                                   ...
# 96   971               Guadeloupe                                   322
# 97   972               Martinique                                   330
# 98   973                   Guyane                                   117
# 99   974               La Réunion                                   857
# 100  976                  Mayotte                                    31
#
#     Salaire net horaire moyen 2022  Chirurgien dentiste (en nombre) 2023  \
# 0                            15.96                                   321
# 1                            14.46                                   226
# 2                            14.19                                   168
# 3                             14.6                                    90
# 4                            13.99                                    89
# ..                             ...                                   ...
# 96                           15.21                                   207
# 97                           15.02                                   215
# 98                           15.43                                    81
# 99                           14.26                                   539
# 100  N/A - résultat non disponible                                    13
#
#         Population municipale 2022  Estimations de population 2024  \
# 0                           671289                          679498
# 1                           525558                          521632
# 2                           334715                          332708
# 3                           167179                          168161
# 4                           141677                          141661
# ..                             ...                             ...
# 96                          383569                          378561
# 97                          361019                          349925
# 98                          288382                          295385
# 99                          881348                          885700
# 100  N/A - résultat non disponible                          320901
#
#     Nb de pers. âgées de 65 ans ou + 2021     Nb de ménages fiscaux 2021  \
# 0                                  121906                         270138
# 1                                  111675                         224492
# 2                                   94477                         160041
# 3                                   44383                          72855
# 4                                   36270                          65683
# ..                                    ...                            ...
# 96                                  78607  N/A - résultat non disponible
# 97                                  80027                         147620
# 98                                  17149  N/A - résultat non disponible
# 99                                 112104                         334396
# 100         N/A - résultat non disponible  N/A - résultat non disponible
#
#      Médiane du niveau de vie 2021
# 0                            24810
# 1                            20920
# 2                            21500
# 3                            21790
# 4                            22010
# ..                             ...
# 96   N/A - résultat non disponible
# 97                           19770
# 98   N/A - résultat non disponible
# 99                           17070
# 100  N/A - résultat non disponible
#
# [101 rows x 10 columns]

# %% [markdown]
# <br>
#
# ---
# ### 2 - Les départements et leur région
#
# <br>
#
# Le fichier a été téléchargé, puis déposé sur GitHub, pour pouvoir y accéder à l'aide d'un url. \
# On récupère les données du fichier HTML qu'on enregistre dans un data frame. \
# La première ligne du fichier HTML est le nom des colonnes, on l'utilise donc. On ne renomme pas la première colonne car on ne l'utilisera pas.

# %%
# URL GitHub pour le fichier CSV
url = "https://raw.githubusercontent.com/ahina0/projet_outinfo/main/regions-et-departements-francais-converted.html"

# Télécharger le fichier HTML depuis GitHub
response = requests.get(url)
response.raise_for_status()


soup = BeautifulSoup(response.text, 'html.parser')

# step 2: identify the tags containing the data
# assume the data is in <tr> tags with <td> for each column
rows = soup.find_all('tr')

# step 3: extract and structure the data
data = []
for row in rows:
    cells = row.find_all('td')
    if len(cells) == 3:  # Number, Department, Region
        num = cells[0].get_text(strip=True)        # Number
        dept = cells[1].get_text(strip=True)       # Department
        region = cells[2].get_text(strip=True)     # Region
        data.append([num, dept, region])

# step 4: create a DataFrame with the extracted data
dept_region = pd.DataFrame(data)
dept_region.columns = dept_region.iloc[0]
dept_region = dept_region[1:].reset_index(drop=True)
dept_region
# Out:
# 0   ‌NUMÉRODépartement              DÉPARTEMENT                      RÉGION
# 0                   01                      Ain        Auvergne-Rhône-Alpes
# 1                   02                    Aisne             Hauts-de-France
# 2                   03                   Allier        Auvergne-Rhône-Alpes
# 3                   04  Alpes-de-Haute-Provence  Provence-Alpes-Côte d'Azur
# 4                   05             Hautes-Alpes  Provence-Alpes-Côte d'Azur
# ..                 ...                      ...                         ...
# 96                 971               Guadeloupe                  Guadeloupe
# 97                 972               Martinique                  Martinique
# 98                 973                   Guyane                      Guyane
# 99                 974               La Réunion                  La Réunion
# 100                976                  Mayotte                     Mayotte
#
# [101 rows x 3 columns]

# %% [markdown]
# <br>
#
# ---
# ### 3 - Liste, localisation et tarifs des professionnels de santé en France.
#
# <br>
#
# Le fichier était trop lourd pour être téléchargé, et un url est directement disponible depuis la page web pour accéder à ces données. On utilise donc cet url. On a aussi uniquement sélectionné les données correspondant à "médecin généraliste", pour que le fichier soit moins lourd.
#
# Comme le fichier est lourd, cette cellule est longue à s'exécuter.

# %%
# URL du fichier GeoJSON
url = "https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/medecins/exports/geojson?lang=fr&refine=libelle_profession%3A%22M%C3%A9decin%20g%C3%A9n%C3%A9raliste%22&timezone=Europe%2FBerlin"

# Télécharger le fichier GeoJSON
response = requests.get(url, stream=True)

# Charger le GeoJSON dans GeoPandas
geojson_data = response.text
professionnels_sante = gpd.read_file(StringIO(geojson_data))

# Afficher les premières lignes
professionnels_sante
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/local/stow/conda/miniforge3/envs/cremi/share/proj failed
# Skipping field libelle_acte_clinique: unsupported OGR type: 5
#        civilite       column_10  column_11    column_12         column_13  \
# 0         Homme  04.92.43.46.74         45         None  Libéral intégral
# 1         Femme  04.92.53.02.00         45         None  Libéral intégral
# 2         Homme  04.92.57.76.13         45         None  Libéral intégral
# 3         Femme  04.92.51.62.23         45         None  Libéral intégral
# 4         Homme  04.92.52.33.33         45         None  Libéral intégral
# ...         ...             ...        ...          ...               ...
# 263386    Femme  03.22.92.98.34         45  Acupuncteur  Libéral intégral
# 263387    Femme  03.22.48.00.00         45         None  Libéral intégral
# 263388    Femme  03.22.88.49.50         45         None  Libéral intégral
# 263389    Homme  03.22.51.45.64         45         None  Libéral intégral
# 263390    Femme            None         45   Angiologue  Libéral intégral
#
#                                                 column_14 column_15  \
# 0                               Secteur 1 ou conventionné         N
# 1                               Secteur 1 ou conventionné         N
# 2                               Secteur 1 ou conventionné         N
# 3                               Secteur 1 ou conventionné         N
# 4                               Secteur 1 ou conventionné         N
# ...                                                   ...       ...
# 263386  Secteur 2, Signature du contrat d'accès aux soins         O
# 263387                          Secteur 1 ou conventionné         N
# 263388                          Secteur 1 ou conventionné         N
# 263389                          Secteur 1 ou conventionné         N
# 263390  Secteur 2, Signature du contrat d'accès aux soins         O
#
#                             column_16 column_17  column_18  ...  \
# 0       Lecteur de carte Sesam Vitale  NZLH0020       13.0  ...
# 1       Lecteur de carte Sesam Vitale        GS        NaN  ...
# 2       Lecteur de carte Sesam Vitale  DEQP0030      103.0  ...
# 3       Lecteur de carte Sesam Vitale         G        NaN  ...
# 4       Lecteur de carte Sesam Vitale  EBQM0030       92.0  ...
# ...                               ...       ...        ...  ...
# 263386  Lecteur de carte Sesam Vitale         G        NaN  ...
# 263387  Lecteur de carte Sesam Vitale         G        NaN  ...
# 263388  Lecteur de carte Sesam Vitale       CCE        NaN  ...
# 263389  Lecteur de carte Sesam Vitale         G        NaN  ...
# 263390  Lecteur de carte Sesam Vitale  DGQM0010       92.0  ...
#
#            libelle_activite  \
# 0       Opérateur Principal
# 1                      None
# 2       Opérateur Principal
# 3                      None
# 4       Opérateur Principal
# ...                     ...
# 263386                 None
# 263387                 None
# 263388                 None
# 263389                 None
# 263390  Opérateur Principal
#
#                                                   libelle  tarif_1 tarif_2  \
# 0       Injection thérapeutique d'agent pharmacologiqu...    19.18    14.4
# 1                                                    None     None    None
# 2        Électrocardiographie sur au moins 12 dérivations    14.52   13.66
# 3                                                    None     None    None
# 4       Échographie-doppler des vaisseaux cervicocépha...    95.33   95.33
# ...                                                   ...      ...     ...
# 263386                                               None     None    None
# 263387                                               None     None    None
# 263388                                               None     None    None
# 263389                                               None     None    None
# 263390  Échographie-doppler de l'aorte abdominale, de ...    77.43   77.43
#
#        remboursement exoneration_tm                  libelle_phase  \
# 0               None            1.0  Une seule phase de traitement
# 1               None            NaN                           None
# 2               None            2.0  Une seule phase de traitement
# 3               None            NaN                           None
# 4               None            2.0  Une seule phase de traitement
# ...              ...            ...                            ...
# 263386          None            NaN                           None
# 263387          None            NaN                           None
# 263388          None            NaN                           None
# 263389          None            NaN                           None
# 263390          None            2.0  Une seule phase de traitement
#
#        tarif_base_de_remboursement_securite_sociale  \
# 0                                             19.18
# 1                                               NaN
# 2                                             14.52
# 3                                               NaN
# 4                                             95.33
# ...                                             ...
# 263386                                          NaN
# 263387                                          NaN
# 263388                                          NaN
# 263389                                          NaN
# 263390                                        77.43
#
#                                                    concat  \
# 0       IVAN PROTHOYPOLYCLINIQUE DES ALPES DU SUD 3 RU...
# 1           SOPHIE VIGNAT  4A COURS EMILE ZOLA  05000 GAP
# 2       JEAN CHRISTIAN GRIMMONPREZ 7 A-B R CAPITAINE B...
# 3       ANNE LINE MEYER  27 RUE DU FOREST D'ENTRAIS  0...
# 4       YANN ROUSSIN BOUCHARDSELIANCE  5 IMPASSE DE BO...
# ...                                                   ...
# 263386    GENEVIEVE DIDELET  93 RUE VATABLE  80090 AMIENS
# 263387  MARIE CLAIRE MASQUELIER MAISON DE SANTE PLACE ...
# 263388  ANGELIQUE DEBEAULIEU MSP DE CONTOIRE HAMEL 104...
# 263389  PIERRE CHARRIERCABINET MEDICAL  3 PLACE DE L E...
# 263390  VALERIE VAILLANTSELAS CABINET DU DR VALERIE VA...
#
#                         geometry
# 0       POINT (6.07079 44.56808)
# 1        POINT (6.07412 44.5538)
# 2       POINT (6.08263 44.55919)
# 3       POINT (6.09093 44.57099)
# 4       POINT (6.08351 44.56261)
# ...                          ...
# 263386  POINT (2.32052 49.88436)
# 263387   POINT (2.52474 50.0125)
# 263388    POINT (2.547 49.72177)
# 263389  POINT (2.14993 49.95316)
# 263390  POINT (-1.12668 46.1736)
#
# [263391 rows x 56 columns]

# %% [markdown]
# ### <br> <br>
#
# <h2 style="padding:16px; color:white; background:#07D">Etape 2 - Maillons clean et structure</h2>
#
# <br> <br>
#
# ---
# ### 1 -  Statistiques locales en France.
#
# <br>
#
# Le nombre de chirurgiens dentistes n'est d'aucune utilité, car les chirurgiens dentistes ne figurent pas dans la database sur les professionnels de santé. On supprime donc cette colonne.

# %%
statistiques = statistiques.drop(columns=["Chirurgien dentiste (en nombre) 2023"]) # drop the specified column
statistiques.head() # display the first rows
# Out:
#   Code                  Libellé  Médecin généraliste (en nombre) 2023  \
# 0   01                      Ain                                   435
# 1   02                    Aisne                                   372
# 2   03                   Allier                                   278
# 3   04  Alpes-de-Haute-Provence                                   169
# 4   05             Hautes-Alpes                                   182
#
#   Salaire net horaire moyen 2022 Population municipale 2022  \
# 0                          15.96                     671289
# 1                          14.46                     525558
# 2                          14.19                     334715
# 3                           14.6                     167179
# 4                          13.99                     141677
#
#    Estimations de population 2024 Nb de pers. âgées de 65 ans ou + 2021  \
# 0                          679498                                121906
# 1                          521632                                111675
# 2                          332708                                 94477
# 3                          168161                                 44383
# 4                          141661                                 36270
#
#   Nb de ménages fiscaux 2021 Médiane du niveau de vie 2021
# 0                     270138                         24810
# 1                     224492                         20920
# 2                     160041                         21500
# 3                      72855                         21790
# 4                      65683                         22010

# %% [markdown]
# <br>
#
# ---
# ### 2 -  Les départements et leur région
#
# <br>
#
# On ajoute la colonne des régions à la data frame des statistiques locales françaises. Les départements sont déjà dans l'ordre croissant de leur numéro dans les deux data frame, donc aucune manipulation supplémentaire n'est nécéssaire.

# %%
statistiques['Région'] = dept_region.RÉGION # the "RÉGION" column in dept_region is added to statistiques
statistiques.head() #display the first rows
# Out:
#   Code                  Libellé  Médecin généraliste (en nombre) 2023  \
# 0   01                      Ain                                   435
# 1   02                    Aisne                                   372
# 2   03                   Allier                                   278
# 3   04  Alpes-de-Haute-Provence                                   169
# 4   05             Hautes-Alpes                                   182
#
#   Salaire net horaire moyen 2022 Population municipale 2022  \
# 0                          15.96                     671289
# 1                          14.46                     525558
# 2                          14.19                     334715
# 3                           14.6                     167179
# 4                          13.99                     141677
#
#    Estimations de population 2024 Nb de pers. âgées de 65 ans ou + 2021  \
# 0                          679498                                121906
# 1                          521632                                111675
# 2                          332708                                 94477
# 3                          168161                                 44383
# 4                          141661                                 36270
#
#   Nb de ménages fiscaux 2021 Médiane du niveau de vie 2021  \
# 0                     270138                         24810
# 1                     224492                         20920
# 2                     160041                         21500
# 3                      72855                         21790
# 4                      65683                         22010
#
#                        Région
# 0        Auvergne-Rhône-Alpes
# 1             Hauts-de-France
# 2        Auvergne-Rhône-Alpes
# 3  Provence-Alpes-Côte d'Azur
# 4  Provence-Alpes-Côte d'Azur

# %% [markdown]
# <br>
#
# ---
# ### 3 -  Liste, localisation et tarifs des professionnels de santé en France.
#
# <br>
#
# Les colonnes ayant un nom de type "column_*number*" ne sont pas gardées.

# %%
# keep only columns that do not match the pattern 'column_"number"'
filtered_columns = [col for col in professionnels_sante.columns if not col.startswith("column_")]
professionnels_sante = professionnels_sante[filtered_columns]

professionnels_sante.head()
# Out:
#   civilite                         nom  \
# 0    Homme                IVAN PROTHOY
# 1    Femme               SOPHIE VIGNAT
# 2    Homme  JEAN CHRISTIAN GRIMMONPREZ
# 3    Femme             ANNE LINE MEYER
# 4    Homme       YANN ROUSSIN BOUCHARD
#
#                                              adresse   libelle_profession  \
# 0  POLYCLINIQUE DES ALPES DU SUD 3 RUE ANTONIN CO...  Médecin généraliste
# 1                     4A COURS EMILE ZOLA  05000 GAP  Médecin généraliste
# 2  7 A-B R CAPITAINE BRESSON RESIDENCE LE PARC  0...  Médecin généraliste
# 3              27 RUE DU FOREST D'ENTRAIS  05000 GAP  Médecin généraliste
# 4            SELIANCE  5 IMPASSE DE BONNE  05000 GAP  Médecin généraliste
#
#   type_dacte_realise                                           nom_acte  \
# 0     Acte technique  Actes médicaux sur les articulations pour évac...
# 1      Acte clinique                                               None
# 2     Acte technique                         Électrocardiogramme (ECG),
# 3      Acte clinique                                               None
# 4     Acte technique  Echodoppler des artères (hors artères intratho...
#
#   coordonnees commune code_insee  \
# 0        None     Gap      05061
# 1        None     Gap      05061
# 2        None     Gap      05061
# 3        None     Gap      05061
# 4        None     Gap      05061
#
#                                         epci_name  ...     libelle_activite  \
# 0  Communauté d'agglomération Gap-Tallard-Durance  ...  Opérateur Principal
# 1  Communauté d'agglomération Gap-Tallard-Durance  ...                 None
# 2  Communauté d'agglomération Gap-Tallard-Durance  ...  Opérateur Principal
# 3  Communauté d'agglomération Gap-Tallard-Durance  ...                 None
# 4  Communauté d'agglomération Gap-Tallard-Durance  ...  Opérateur Principal
#
#                                              libelle tarif_1 tarif_2  \
# 0  Injection thérapeutique d'agent pharmacologiqu...   19.18    14.4
# 1                                               None    None    None
# 2   Électrocardiographie sur au moins 12 dérivations   14.52   13.66
# 3                                               None    None    None
# 4  Échographie-doppler des vaisseaux cervicocépha...   95.33   95.33
#
#   remboursement exoneration_tm                  libelle_phase  \
# 0          None            1.0  Une seule phase de traitement
# 1          None            NaN                           None
# 2          None            2.0  Une seule phase de traitement
# 3          None            NaN                           None
# 4          None            2.0  Une seule phase de traitement
#
#   tarif_base_de_remboursement_securite_sociale  \
# 0                                        19.18
# 1                                          NaN
# 2                                        14.52
# 3                                          NaN
# 4                                        95.33
#
#                                               concat                  geometry
# 0  IVAN PROTHOYPOLYCLINIQUE DES ALPES DU SUD 3 RU...  POINT (6.07079 44.56808)
# 1      SOPHIE VIGNAT  4A COURS EMILE ZOLA  05000 GAP   POINT (6.07412 44.5538)
# 2  JEAN CHRISTIAN GRIMMONPREZ 7 A-B R CAPITAINE B...  POINT (6.08263 44.55919)
# 3  ANNE LINE MEYER  27 RUE DU FOREST D'ENTRAIS  0...  POINT (6.09093 44.57099)
# 4  YANN ROUSSIN BOUCHARDSELIANCE  5 IMPASSE DE BO...  POINT (6.08351 44.56261)
#
# [5 rows x 32 columns]

# %% [markdown]
# <br>
#
# On ne garde que les colonnes qui nous intéressent pour les analyses.
#
# On visualise les colonnes restantes :

# %%
professionnels_sante.columns # visualisation of the remaining columns
# Out:
# Index(['civilite', 'column_10', 'column_11', 'column_12', 'column_13',
#        'column_14', 'column_15', 'column_16', 'column_17', 'column_18',
#        'column_19', 'column_20', 'column_21', 'column_22', 'column_23',
#        'column_24', 'column_25', 'column_26', 'column_27', 'column_28',
#        'column_29', 'column_30', 'column_31', 'column_32', 'column_33', 'nom',
#        'adresse', 'libelle_profession', 'type_dacte_realise', 'nom_acte',
#        'coordonnees', 'commune', 'code_insee', 'epci_name', 'dep_name',
#        'reg_name', 'epci_code', 'reg_code', 'dep_code', 'activite_principale',
#        'code', 'phase', 'libelle_regroupement', 'accord_prealable',
#        'code_ccam_activite_phase', 'regroupement', 'libelle_activite',
#        'libelle', 'tarif_1', 'tarif_2', 'remboursement', 'exoneration_tm',
#        'libelle_phase', 'tarif_base_de_remboursement_securite_sociale',
#        'concat', 'geometry'],
#       dtype='object')

# %% [markdown]
# <br>
#
# La colonne "libelle_profession" est inutile, car on a conservé que les lignes qui correspondent aux médecins généralistes dans la base de données initiale.
#
# Pour plus de complexité à traiter les données, on décide de ne pas conserver les colonnes de la commune, du département et de la région. On créera la colonne du département à partir de la colonne adresse.
#
# Le nom du médecin, le type d'acte réalisé et autres informations sur l'activité du médecin ne nous interesse pas.
#
# On ne conserve donc que les colonnes sur le genre du médecin, l'adresse, et le tarif de la consultation.

# %%
columns_to_keep = ["civilite", "adresse", "tarif_1", "tarif_2", "remboursement", "tarif_base_de_remboursement_securite_sociale"] # the columns to keep
professionnels_sante = professionnels_sante[columns_to_keep]

professionnels_sante.head(20)
# Out:
#    civilite                                            adresse tarif_1  \
# 0     Homme  POLYCLINIQUE DES ALPES DU SUD 3 RUE ANTONIN CO...   19.18
# 1     Femme                     4A COURS EMILE ZOLA  05000 GAP    None
# 2     Homme  7 A-B R CAPITAINE BRESSON RESIDENCE LE PARC  0...   14.52
# 3     Femme              27 RUE DU FOREST D'ENTRAIS  05000 GAP    None
# 4     Homme            SELIANCE  5 IMPASSE DE BONNE  05000 GAP   95.33
# 5     Homme  CABINET DU DR FRIEDERICH PLACE DU VILLAGE CABI...   14.52
# 6     Homme  CABINET DU DR FRIEDERICH PLACE DU VILLAGE CABI...   29.68
# 7     Homme           133 RUE DES ECOLES  05230 LA BATIE NEUVE    None
# 8     Femme            230 AVENUE DE LA CALIFORNIE  06200 NICE    41.8
# 9     Femme                 4 AVENUE DE L EST  06220 VALLAURIS    None
# 10    Femme                 4 AVENUE DE L EST  06220 VALLAURIS    None
# 11    Homme  CABINET DU DR BRUNO DUBREUIL  7 AVENUE DES FRE...   69.12
# 12    Femme  LE FLOREAL ENTREE A 55 AVENUE DE LA GARE  0680...   12.73
# 13    Femme  11 RUE DU DOCTEUR PAUL BALOUX  06150 CANNES LA...    None
# 14    Femme  CABINET DU DR MARION VALLOT CTRE MEDICAL DE LA...    None
# 15    Femme  CABINET DU DR MARION VALLOT CTRE MEDICAL DE LA...    None
# 16    Femme  LE MARLY 33B BOULEVARD DE LA LIBERATION  05000...   12.73
# 17    Homme  CABINET DE GROUPE LE VILLAGE CABINET MEDICAL  ...    None
# 18    Femme  RTE DE ST JEAN MSP DU HAUT CHAMPSAUR  05260 ST...   19.95
# 19    Homme  CABINET MEDICAL 133 RUE DES ECOLES  05230 LA B...    None
#
#    tarif_2 remboursement  tarif_base_de_remboursement_securite_sociale
# 0     14.4          None                                         19.18
# 1     None          None                                           NaN
# 2    13.66          None                                         14.52
# 3     None          None                                           NaN
# 4    95.33          None                                         95.33
# 5    13.66          None                                         14.52
# 6    25.99          None                                         29.68
# 7     None          None                                           NaN
# 8     41.8          None                                         41.80
# 9     None          None                                           NaN
# 10    None          None                                           NaN
# 11   69.12          None                                         69.12
# 12     9.8          None                                         12.73
# 13    None          None                                           NaN
# 14    None          None                                           NaN
# 15    None          None                                           NaN
# 16     9.8          None                                         12.73
# 17    None          None                                           NaN
# 18   19.95          None                                         19.95
# 19    None          None                                           NaN

# %% [markdown]
# <br>
#
# On remarque que beaucoup de valeurs de la colonne "remboursement" semblent avoir la valeur "None". On compte le nombre de ces valeurs pour décider de garder cette colonne ou non.

# %%
# count the number of None values in the "remboursement" column. It is either Na or "None"
none_count = professionnels_sante[(professionnels_sante["remboursement"].isna()) | (professionnels_sante["remboursement"] == "None")].shape[0]
total_rows = professionnels_sante.shape[0] # count the number of rows in the dataframe
print(f"Pourcentage de valeurs None dans la colonne remboursement : {(none_count/total_rows)*100:.0f}%.") # prints the percentage of None values, with no decimal

professionnels_sante["remboursement"] = professionnels_sante["remboursement"].fillna("None") # if Na, write "None"
# display the repartition of the values of the remboursement column
professionnels_sante.groupby("remboursement").count()["civilite"].plot.bar()
# Out:
# Pourcentage de valeurs None dans la colonne remboursement : 99%.
# <Axes: xlabel='remboursement'>

# %% [markdown]
# On décide de supprimer cette colonne.

# %%
professionnels_sante = professionnels_sante.drop(columns=["remboursement"])
professionnels_sante.head()
# Out:
#   civilite                                            adresse tarif_1 tarif_2  \
# 0    Homme  POLYCLINIQUE DES ALPES DU SUD 3 RUE ANTONIN CO...   19.18    14.4
# 1    Femme                     4A COURS EMILE ZOLA  05000 GAP    None    None
# 2    Homme  7 A-B R CAPITAINE BRESSON RESIDENCE LE PARC  0...   14.52   13.66
# 3    Femme              27 RUE DU FOREST D'ENTRAIS  05000 GAP    None    None
# 4    Homme            SELIANCE  5 IMPASSE DE BONNE  05000 GAP   95.33   95.33
#
#    tarif_base_de_remboursement_securite_sociale
# 0                                         19.18
# 1                                           NaN
# 2                                         14.52
# 3                                           NaN
# 4                                         95.33

# %%
Les colonnes tarif_1 et tarif_2

# %% [markdown]
# On rappelle que le but du projet étant de manipuler des données, on décide de ne pas conserver les colonnes de la commune, du département et de la région. On va maintenant créer nous même une colonne postal_code à partir de la colonne "adresse".

# %%
#function to have the postal code 
def extraire_code_postal(adresse):
    import re
    # 5 digits in address
    match = re.search(r"\d{5}", str(adresse))
    return match.group(0) if match else None

# add "postal_code" column to existing df
professionnels_sante["postal_code"] = professionnels_sante["adresse"].apply(extraire_code_postal)

# print dataframe
professionnels_sante.head()
# Out:
#   civilite                                            adresse tarif_1 tarif_2  \
# 0    Homme  POLYCLINIQUE DES ALPES DU SUD 3 RUE ANTONIN CO...   19.18    14.4
# 1    Femme                     4A COURS EMILE ZOLA  05000 GAP    None    None
# 2    Homme  7 A-B R CAPITAINE BRESSON RESIDENCE LE PARC  0...   14.52   13.66
# 3    Femme              27 RUE DU FOREST D'ENTRAIS  05000 GAP    None    None
# 4    Homme            SELIANCE  5 IMPASSE DE BONNE  05000 GAP   95.33   95.33
#
#    tarif_base_de_remboursement_securite_sociale postal_code dep_code
# 0                                         19.18       05000       05
# 1                                           NaN       05000       05
# 2                                         14.52       05000       05
# 3                                           NaN       05000       05
# 4                                         95.33       05000       05

# %% [markdown]
# Maintenant, on crée une colonne "dep_code" à partir de notre colonne "costal_code" en sélectionnant les deux premier chiffres de chaque code postal.

# %%
departements_speciaux = {"971", "972", "973", "974", "975", "976", "977", "978", "984", "986", "987", "988", "989"}

#function to extract the department number
def extraire_dep_code(postal_code):
    if postal_code is None:
        return None
    if postal_code[:3] in departements_speciaux:
        return postal_code[:3]
    return postal_code[:2]


professionnels_sante["dep_code"] = professionnels_sante["postal_code"].apply(extraire_dep_code)
professionnels_sante.head()
# Out:
#   civilite                                            adresse tarif_1 tarif_2  \
# 0    Homme  POLYCLINIQUE DES ALPES DU SUD 3 RUE ANTONIN CO...   19.18    14.4
# 1    Femme                     4A COURS EMILE ZOLA  05000 GAP    None    None
# 2    Homme  7 A-B R CAPITAINE BRESSON RESIDENCE LE PARC  0...   14.52   13.66
# 3    Femme              27 RUE DU FOREST D'ENTRAIS  05000 GAP    None    None
# 4    Homme            SELIANCE  5 IMPASSE DE BONNE  05000 GAP   95.33   95.33
#
#    tarif_base_de_remboursement_securite_sociale postal_code dep_code
# 0                                         19.18       05000       05
# 1                                           NaN       05000       05
# 2                                         14.52       05000       05
# 3                                           NaN       05000       05
# 4                                         95.33       05000       05

# %% [markdown]
# ### <br> <br>
#
# <h2 style="padding:16px; color:white; background:#07D">Etape 3 - Analyses</h2>
#
# <br> <br>

# %% [markdown]
# Calcul de la moyenne du nombre de médecins généralistes par régions en 2023

# %%
df = pd.DataFrame(statistiques)

# calculation of the average number of general practitioners per region
moyennes_par_region = df.groupby("Région")["Médecin généraliste (en nombre) 2023"].mean()

print(moyennes_par_region)
# Out:
# Région
# Auvergne-Rhône-Alpes           606.333333
# Bourgogne-Franche-Comté        210.375000
# Bretagne                       548.750000
# Centre-Val de Loire            293.333333
# Corse                          484.500000
# Grand Est                      488.700000
# Guadeloupe                     322.000000
# Guyane                         117.000000
# Hauts-de-France               1024.600000
# Ile-de-France                 1135.250000
# La Réunion                     857.000000
# Martinique                     330.000000
# Mayotte                         31.000000
# Normandie                      649.800000
# Nouvelle-Aquitaine             552.166667
# Occitanie                      451.769231
# Pays de la Loire               632.800000
# Provence-Alpes-Côte d'Azur     984.500000
# Name: Médecin généraliste (en nombre) 2023, dtype: float64

# %%
# Create a box chart
mp.figure(figsize=(12, 6))
palette = sb.color_palette("husl", len(statistiques["Région"].unique())) 

sb.boxplot(
    x="Région",
    y="Médecin généraliste (en nombre) 2023",
    data=statistiques,
    palette=palette
)

mp.title("Répartition du nombre de médecins généralistes par région (2023)", fontsize=14)
mp.xticks(rotation=90)
mp.xlabel("Région")
mp.ylabel("Nombre de médecins généralistes")
mp.tight_layout()

mp.show()

# %% [markdown]
# On veut créer, à partir de notre table "professionnels_sante", une nouvelle table "professionnels_nb_dep" qui contient dans la première colonne les départemets qui apparaissent dans la colonne "dep_code" de "professionnels_sante", et dans la deuxième colonne le nombre de fois où chaque département apparait dans la table "professionnels_sante". Cela nous permettra d'obtenir le combre de médecins par département en 2024 (puis que ces données datent de décembre 2024).

# %%
professionnels_nb_dep = professionnels_sante["dep_code"].value_counts().reset_index()
professionnels_nb_dep.columns = ["dep_code", "count"]

#sort in ascending order
professionnels_nb_dep = professionnels_nb_dep.sort_values(by="dep_code").reset_index(drop=True)

print(professionnels_nb_dep)
# Out:
#     dep_code  count
# 0         01   2534
# 1         02   1444
# 2         03   1114
# 3         04    714
# 4         05   1302
# ..       ...    ...
# 97       973    376
# 98       974   3680
# 99       976    119
# 100       98     37
# 101       99      4
#
# [102 rows x 2 columns]

# %%
# compare data from 2023 and 2024 (merging tables)
comparaison = pd.merge(
    professionnels_nb_dep,
    statistiques,
    left_on="dep_code",
    right_on="Code",
    how="inner"
)

# rename columns
comparaison.rename(columns={
    "Médecin généraliste (en nombre) 2023": "Médecins généralistes 2023"
}, inplace=True)

comparaison.rename(columns={
    "count": "Médecins généralistes 2024"
}, inplace=True)


mp.figure(figsize=(15, 8))
bar_width = 0.35
indices = range(len(comparaison))

#histogram 2023
mp.bar(indices, comparaison["Médecins généralistes 2023"], width=bar_width, label="Médecins généralistes 2023")

#histogram 2024
mp.bar(
    [i + bar_width for i in indices],
    comparaison["Médecins généralistes 2024"],
    width=bar_width,
    label="Médecins généralistes 2024"
)

mp.xlabel("Départements")
mp.ylabel("Nombre")
mp.title("Comparaison des médecins généralistes par département (2023 vs 2024)")
mp.xticks([i + bar_width / 2 for i in indices], comparaison["dep_code"], rotation=45, fontsize=7)
mp.legend()


mp.tight_layout()
mp.show()

# %% [markdown]
# On compare ces données sur une carte afin de pouvoir faire une analyse plus poussée.

# %%
# load GeoJSON data from GitHub
geojson_url = "https://raw.githubusercontent.com/gregoiredavid/france-geojson/master/departements.geojson"
geo_df = gpd.read_file(geojson_url)

#list of overseas departments to be excluded
outre_mer = {"971", "972", "973", "974", "975", "976", "977", "978", "984", "986", "987", "988", "989"}

# filter to include only metropolitan France
geo_df = geo_df[~geo_df["code"].isin(outre_mer)]

# function to create the interactive map
def create_medical_map(selected_year):
    if selected_year not in [2023, 2024]:
        raise ValueError("Année invalide. Choisissez 2023 ou 2024.")
    
    # choose the column to display according to the year
    colonne = f"Médecins généralistes {selected_year}"
    
    # merge data with geometries
    geo_data = geo_df.merge(comparaison, left_on="code", right_on="dep_code", how="left")
    
    # create map centered on France
    medical_map = folium.Map(location=[46.603354, 1.888334], zoom_start=6)
    
    # add departments with color gradient
    folium.Choropleth(
        geo_data=geo_data,
        data=comparaison,
        columns=["dep_code", colonne],
        key_on="feature.properties.code",
        fill_color="YlGnBu",
        fill_opacity=0.7,
        line_opacity=0.2,
        nan_fill_opacity=0,
        legend_name=f"Médecins généralistes ({selected_year})"
    ).add_to(medical_map)
    
    # add tooltips for each department
    folium.GeoJson(
        geo_data,
        tooltip=folium.GeoJsonTooltip(
            fields=["nom", colonne],
            aliases=["Département:", "Nombre de médecins:"],
            localize=True
        )
    ).add_to(medical_map)
    
    display(HTML(medical_map._repr_html_()))

# widget 
interact(
    create_medical_map,
    selected_year=widgets.SelectionSlider(
        options=[2023, 2024],
        description='Année:',
        orientation='horizontal',
        layout={'width': '600px'}
    )
)
# Out:
# interactive(children=(SelectionSlider(description='Année:', layout=Layout(width='600px'), options=(2023, 2024)…
# <function __main__.create_medical_map(selected_year)>

# %% [markdown]
# Ici, nous avons le nombre de médecins par département en 2023 et 2024. <br>
# Il n'y a pas de différence très notable entre les deux années.<br>
# Cependant, ce qui compte réellement, c'est le ratio entre le nombre de médecins et la population totale par département.

# %% [markdown]
# Pour cela, il nous faut les données de population par 2023. On télécharge donc des données en .json.

# %%
url = "https://raw.githubusercontent.com/ahina0/projet_outinfo/main/demographyref-france-pop-legale-departement.json"

# download the JSON file from GitHub
response = requests.get(url)
response.raise_for_status()

# load data into a DataFrame
pop_2023 = pd.read_json(response.text)

print(pop_2023.head())
# Out:
#   reg_code                   reg_name dep_code          dep_name  \
# 0     [84]     [Auvergne-Rhône-Alpes]     [01]             [Ain]
# 1     [27]  [Bourgogne-Franche-Comté]     [71]  [Saône-et-Loire]
# 2     [32]          [Hauts-de-France]     [80]           [Somme]
# 3     [04]               [La Réunion]    [974]      [La Réunion]
# 4     [76]                [Occitanie]     [34]         [Hérault]
#
#    arrdep_count  can_count  dep_pop_mun  dep_pop_tot  census_year  start_year  \
# 0           4.0       23.0       657856       673801         2020        2023
# 1           5.0       29.0       551063       566292         2020        2023
# 2           4.0       23.0       568748       578691         2020        2023
# 3           4.0       25.0       863083       872635         2020        2023
# 4           3.0       25.0      1188973      1206907         2020        2023
#
#    geo_year
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022

# %% [markdown]
# Maintenant, on calcule le ratio entre le nombre de médecins généralistes 2023 par département et la population 2023 par départements.

# %%
# verify and correct columns
statistiques["Code"] = statistiques["Code"].apply(lambda x: x[0] if isinstance(x, list) else x)
pop_2023["dep_code"] = pop_2023["dep_code"].apply(lambda x: x[0] if isinstance(x, list) else x)

# convert to strings to avoid merge errors
statistiques["Code"] = statistiques["Code"].astype(str)
pop_2023["dep_code"] = pop_2023["dep_code"].astype(str)

# merge the two tables on the department code
merged_data = statistiques.merge(
    pop_2023,
    left_on="Code",
    right_on="dep_code",
    how="left"
)

# calculate the ratio of physicians/population as a percentage
merged_data["Ratio médecins/population"] = (
    merged_data["Médecin généraliste (en nombre) 2023"] / merged_data["dep_pop_tot"]
) * 100

print(merged_data[["Code", "dep_code", "Médecin généraliste (en nombre) 2023", "dep_pop_tot", "Ratio médecins/population"]].head())
# Out:
#   Code dep_code  Médecin généraliste (en nombre) 2023  dep_pop_tot  \
# 0   01       01                                   435     673801.0
# 1   02       02                                   372     541176.0
# 2   03       03                                   278     344455.0
# 3   04       04                                   169     170060.0
# 4   05       05                                   182     144981.0
#
#    Ratio médecins/population
# 0                   0.064559
# 1                   0.068739
# 2                   0.080707
# 3                   0.099377
# 4                   0.125534

# %% [markdown]
# Affichons les cartes des médecins par département et du ratio par département en 2023 :

# %%
url_geojson = "https://raw.githubusercontent.com/gregoiredavid/france-geojson/master/departements.geojson"
geo_df = gpd.read_file(url_geojson)

# list of overseas departments to be excluded
outre_mer = {"971", "972", "973", "974", "975", "976", "977", "978", "984", "986", "987", "988", "989"}

# filter to include only metropolitan France
geo_df = geo_df[~geo_df["code"].isin(outre_mer)]

# dual card display function: number of doctors and ratio as a percentage
def afficher_cartes():
    # merge statistical data with geometries
    carte_data = geo_df.merge(merged_data, left_on="code", right_on="Code", how="left")

    # create the figure with two sub-graphs
    fig, axes = mp.subplots(1, 2, figsize=(20, 15))

    ax1 = carte_data.plot(
        column="Médecin généraliste (en nombre) 2023",
        cmap="YlGnBu",
        legend=True,
        edgecolor="black",
        linewidth=0.5,
        ax=axes[0]
    )
    ax1.set_title("Nombre de médecins généralistes par département (2023)", fontsize=14)
    ax1.set_axis_off()

    # add annotations for each department
    for x, y, label in zip(carte_data.geometry.centroid.x, carte_data.geometry.centroid.y, carte_data["Médecin généraliste (en nombre) 2023"]):
        axes[0].text(x, y, str(label) if not pd.isna(label) else "", fontsize=6, ha="center", color="black")

    ax2 = carte_data.plot(
        column="Ratio médecins/population",
        cmap="YlGnBu",
        legend=True,
        edgecolor="black",
        linewidth=0.5,
        ax=axes[1]
    )
    ax2.set_title("Ratio Médecins généralistes / Population (2023) [%]", fontsize=14)
    ax2.set_axis_off()

    for x, y, label in zip(carte_data.geometry.centroid.x, carte_data.geometry.centroid.y, carte_data["Ratio médecins/population"]):
        axes[1].text(x, y, f"{label:.2f}%" if not pd.isna(label) else "", fontsize=6, ha="center", color="black")

    # adjust the layout
    mp.tight_layout()
    mp.show()

afficher_cartes()

# %% [markdown]
# Faison de même pour les données de 2024 :

# %%
statistiques["Code"] = statistiques["Code"].apply(lambda x: x[0] if isinstance(x, list) else x)
pop_2023["dep_code"] = pop_2023["dep_code"].apply(lambda x: x[0] if isinstance(x, list) else x)

statistiques["Code"] = statistiques["Code"].astype(str)
professionnels_nb_dep["dep_code"] = professionnels_nb_dep["dep_code"].astype(str)

merged_data = statistiques.merge(
    professionnels_nb_dep,
    left_on="Code",
    right_on="dep_code",
    how="left"
)

merged_data["Ratio médecins/population"] = (
    merged_data["count"] / merged_data["Estimations de population 2024"]
) * 100

print(merged_data[["Code", "dep_code", "count", "Estimations de population 2024", "Ratio médecins/population"]].head())
# Out:
#   Code dep_code   count  Estimations de population 2024  \
# 0   01       01  2534.0                          679498
# 1   02       02  1444.0                          521632
# 2   03       03  1114.0                          332708
# 3   04       04   714.0                          168161
# 4   05       05  1302.0                          141661
#
#    Ratio médecins/population
# 0                   0.372922
# 1                   0.276824
# 2                   0.334828
# 3                   0.424593
# 4                   0.919096

# %%
# dual card display function: number of doctors and ratio as a percentage
def afficher_cartes():
    # merge statistical data with geometrie
    carte_data = geo_df.merge(merged_data, left_on="code", right_on="Code", how="left")

    # create the figure with two sub-graphs
    fig, axes = mp.subplots(1, 2, figsize=(20, 15))

    ax1 = carte_data.plot(
        column="count",
        cmap="YlGnBu",
        legend=True,
        edgecolor="black",
        linewidth=0.5,
        ax=axes[0]
    )
    ax1.set_title("Nombre de médecins généralistes par département (2024)", fontsize=14)
    ax1.set_axis_off()

    # add annotations for each department
    for x, y, label in zip(carte_data.geometry.centroid.x, carte_data.geometry.centroid.y, carte_data["count"]):
        axes[0].text(x, y, str(label) if not pd.isna(label) else "", fontsize=6, ha="center", color="black")

    ax2 = carte_data.plot(
        column="Ratio médecins/population",
        cmap="YlGnBu",
        legend=True,
        edgecolor="black",
        linewidth=0.5,
        ax=axes[1]
    )
    ax2.set_title("Ratio Médecins généralistes / Population (2024) [%]", fontsize=14)
    ax2.set_axis_off()

    for x, y, label in zip(carte_data.geometry.centroid.x, carte_data.geometry.centroid.y, carte_data["Ratio médecins/population"]):
        axes[1].text(x, y, f"{label:.2f}%" if not pd.isna(label) else "", fontsize=6, ha="center", color="black")

    # adjust layout
    mp.tight_layout()
    mp.show()


afficher_cartes()

# %% [markdown]
# Lorsqu'on regarde les cartes des ratios entre 2023 et 2024 il semble qu'il y a, de manière générale, beaucoup moins de médecins par habitant en 2024, ce qui est préocupant en terme de santé. Cependant, les chiffres de population utilisés pour l'année 2024 sont des estimations, ils ne reflètent donc pas complétement la réalité.
